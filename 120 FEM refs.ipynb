# %%
from IPython.display import Image

# %% [markdown]
# FEM software references
# =======================
#
# Incomplete list of the software that I found useful
#
# Meshing
# -------
# + Gmsh http://geuz.org/gmsh/
# + Netgen http://sourceforge.net/projects/netgen-mesher/
#
# Solving
# -------
# + FEniCS http://fenicsproject.org/
# + Elmer http://www.csc.fi/english/pages/elmer/index_html
# + Many others: getdp, sfepy,...
#
# Postprocessing
# --------------
# + ParaView http://www.paraview.org/
# + Mayavi http://code.enthought.com/projects/mayavi/
#
# All in one
# ----------
# + FEMM http://www.femm.info/wiki/HomePage
# + Agros2D http://www.agros2d.org/

# %% [markdown]
# Examples
# ========
#
# Geometry definition for electrostatic model of an octopole wire trap

# %%
Image("fig/octopole-inside.png")

# %% [markdown]
# Electron trajectories between trap and detector

# %%
Image("fig/ss0.5.png")

# %% [markdown]
# Optimization of coil current for electron focusing in ES-MPT experiment

# %%
Image("fig/ss_1x_2x_4x_current.png")

# %% [markdown]
# Electron trajectories in the ES-MPT instrument (bad example :)

# %%
Image("fig/ss-rf-4mm.png")

# %% [markdown]
# Ion distributions in a damaged 22-pole trap

# %%
Image("fig/ss-H-CH.png")
